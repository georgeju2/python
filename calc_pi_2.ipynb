# %%
import os

accu = 1
for i in range(1, 1000000):
    #print(2*i+1, 2*i, 2*i+2)
    f = float((2*i)*2*(i+1))/(2*i+1)/ (2*i+1)
    accu = accu *f
    #print(accu*4)
print(accu*4)
# Out:
# 3.1415934389879703
